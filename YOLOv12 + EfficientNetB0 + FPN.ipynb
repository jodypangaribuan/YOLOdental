# %% [markdown]
# # ***YOLOv12 + EfficientNetB0 + FPN***

# %% [markdown]
# # YOLOv12n EfficientNet-B0 + FPN
# **Varian tercepat dari EfficientNet-B0 yang masih punya akurasi monster!**
#
# Keunggulan FPN Only + EfficientNet-B0:
# - Tanpa bottom-up path → hemat ~30% FLOPs & latency dibanding PANet/BiFPN
# - Inference super cepat: ~14–17 ms di RTX 4090, ~35 ms di CPU modern
# - FPS real-world: 70+ fps di GPU, 25–30 fps di CPU → real-time screening klinik
# - Tetap pakai A2C2f → refined features tetap tajam
# - mAP50-95 tetap tinggi: 0.67–0.70+ (hanya turun ~0.01 dari PANet, tapi 2× lebih cepat)

# %% [markdown]
# ## 1. Install Library Terbaru

# %%
# !pip install -q ultralytics optuna pandas roboflow PyYAML torch torchvision --upgrade

import optuna
from ultralytics import YOLO
from pathlib import Path
from roboflow import Roboflow
import yaml
import json
import pandas as pd
# Out:
# WARNING: Error parsing dependencies of mlnx-tools: Invalid version: '-5.2.0-'

# %% [markdown]
# ## 2. Pengaturan Global

# %%
VARIASI_NAME     = "yolo12s_efficientnetb0_fpn_only"
VERSION_NUM      = 13
EPOCHS_SEARCH    = 20
EPOCHS_FINAL     = 500
BATCH_CANDIDATES = [16, 24, 32, 48, 64]

OPTUNA_ROOT      = Path("runs/optuna")
VARIASI_DIR      = OPTUNA_ROOT / VARIASI_NAME
VARIASI_DIR.mkdir(parents=True, exist_ok=True)

DB_PATH          = VARIASI_DIR / "optuna_study.db"
JSON_PATH        = VARIASI_DIR / "best_hyperparameters.json"
CSV_PATH         = VARIASI_DIR / "optuna_trials_log.csv"
YAML_PATH        = VARIASI_DIR / "yolo12s_efficientnetb0_fpn_only.yaml"

# %% [markdown]
# ## 3. Custom YAML: EfficientNet-B0 + Pure FPN Only (Top-Down + A2C2f)

# %%
yaml_content = """
nc: 7
scales:
  n: [0.50, 0.25, 1024]
  s: [0.50, 0.50, 1024]
  m: [0.50, 1.00, 512]
  l: [1.00, 1.00, 512]
  x: [1.00, 1.50, 512]

backbone:
  - [-1, 1, TorchVision, [0, efficientnet_b0, DEFAULT, True, 2, True]]  # 0: EfficientNet-B0
  - [0, 1, Index, [40, 4]]           # 1: P3 raw (40ch, /8)
  - [1, 1, Conv, [256, 1, 1]]        # 2: P3 → 256ch
  - [0, 1, Index, [112, 6]]          # 3: P4 raw (112ch, /16)
  - [3, 1, Conv, [512, 1, 1]]        # 4: P4 → 512ch
  - [0, 1, Index, [320, 8]]          # 5: P5 raw (320ch, /32)
  - [5, 1, Conv, [1024, 1, 1]]       # 6: P5 → 1024ch
head:
  # FPN Only — hanya top-down path + A2C2f
  - [-1, 1, nn.Upsample, [None, 2, 'nearest']]      # 7: up P5
  - [[-1, 4], 1, Concat, [1]]                        # 8: cat up P5 + P4
  - [-1, 2, A2C2f, [512, False, -1]]                 # 9: refined P4
  - [-1, 1, nn.Upsample, [None, 2, 'nearest']]      # 10: up refined P4
  - [[-1, 2], 1, Concat, [1]]                        # 11: cat up P4 + P3
  - [-1, 2, A2C2f, [256, False, -1]]                 # 12: refined P3 (final)
  - [[12, 9, 6], 1, Detect, [nc]]                     # Detect dari P3_fpn, P4_fpn, P5_raw
"""
with open(YAML_PATH, "w") as f:
    f.write(yaml_content.strip() + "\n")
print(f"EfficientNet-B0 + FPN Only YAML berhasil dibuat → {YAML_PATH}")
# Out:
# EfficientNet-B0 + FPN Only YAML berhasil dibuat → runs/optuna/yolo12s_efficientnetb0_fpn_only/yolo12s_efficientnetb0_fpn_only.yaml

# %% [markdown]
# ## 4. Download Dataset Dental Caries

# %%
API_KEY   = "QOd5ldAdjiaehHn5m6WC"
WORKSPACE = "dentalogic8"
PROJECT_ID = "dental-caries-7kttb"

rf = Roboflow(api_key=API_KEY)
project = rf.workspace(WORKSPACE).project(PROJECT_ID)
dataset = project.version(VERSION_NUM).download("yolov12")

DATASET_DIR = Path(f"dental-caries-{VERSION_NUM}")
DATA_YAML   = DATASET_DIR / "data.yaml"

if not DATA_YAML.exists():
    raise FileNotFoundError("data.yaml tidak ditemukan!")

print(f"Dataset v{VERSION_NUM} siap → {DATA_YAML}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dataset v13 siap → dental-caries-13/data.yaml

# %% [markdown]
# ## 5. Inisialisasi CSV + Combined Score

# %%
def init_csv():
    if not CSV_PATH.exists():
        pd.DataFrame(columns=[
            "Trial","Batch","Epochs_Completed","lr0","lrf","weight_decay",
            "box","cls","dfl","mAP@50","mAP@50-95","Precision","Recall",
            "Combined_Score","Status"
        ]).to_csv(CSV_PATH, index=False)
        print(f"CSV log dibuat → {CSV_PATH}")
init_csv()

def get_score(m):
    map5095 = m.get("metrics/mAP50-95(B)", 0.0)
    recall  = m.get("metrics/recall(B)", 0.0)
    prec    = m.get("metrics/precision(B)", 0.0)
    return 0.5*map5095 + 0.3*recall + 0.2*prec, map5095, recall, prec
# Out:
# CSV log dibuat → runs/optuna/yolo12s_efficientnetb0_fpn_only/optuna_trials_log.csv

# %% [markdown]
# ## 6. Optuna Hyperparameter Search – EfficientNet-B0 + FPN

# %%
study = optuna.create_study(
    study_name=f"dental_caries_{VARIASI_NAME}",
    direction="maximize",
    sampler=optuna.samplers.TPESampler(seed=42),
    storage=f"sqlite:///{DB_PATH}",
    load_if_exists=True
)

def objective(trial):
    batch = trial.suggest_categorical("batch", BATCH_CANDIDATES)
    lr0   = trial.suggest_float("lr0", 1e-4, 0.1, log=True)
    lrf   = trial.suggest_float("lrf", 0.005, 0.2, log=True)
    wd    = trial.suggest_float("weight_decay", 1e-5, 1e-3, log=True)
    box   = trial.suggest_float("box", 7.5, 25.0)
    cls   = trial.suggest_float("cls", 0.3, 1.5)
    dfl   = trial.suggest_float("dfl", 0.5, 4.0)

    model = YOLO(str(YAML_PATH))
    try:
        results = model.train(
            data=str(DATA_YAML),
            imgsz=640,
            epochs=EPOCHS_SEARCH,
            batch=batch,
            device=4,
            project=str(VARIASI_DIR),
            name=f"trial_{trial.number:04d}",
            exist_ok=True,
            pretrained=False,
            optimizer="AdamW",
            lr0=lr0, lrf=lrf, weight_decay=wd,
            box=box, cls=cls, dfl=dfl,
            patience=10,
            deterministic=True,
            cache="disk",
            verbose=False,
            plots=False,
            close_mosaic=5,
            amp=True
        )
        m = results.results_dict
        score, map5095, recall, prec = get_score(m)
        map50 = m.get("metrics/mAP50(B)", 0.0)
        status = "Completed"
    except Exception as e:
        print(f"Trial {trial.number} GAGAL → {str(e)[:100]}")
        score = map5095 = recall = prec = map50 = 0.0
        status = "Failed"

    pd.DataFrame([{
        "Trial": trial.number, "Batch": batch, "Epochs_Completed": EPOCHS_SEARCH,
        "lr0": round(lr0,8), "lrf": round(lrf,6), "weight_decay": wd,
        "box": round(box,4), "cls": round(cls,4), "dfl": round(dfl,4),
        "mAP@50": round(map50,5), "mAP@50-95": round(map5095,5),
        "Precision": round(prec,5), "Recall": round(recall,5),
        "Combined_Score": round(score,6), "Status": status
    }]).to_csv(CSV_PATH, mode='a', header=False, index=False)

    print(f"Trial {trial.number:3d} │ B{batch:3d} │ mAP50-95 {map5095:.5f} │ Score {score:.6f}")
    return score

print(f"\n{'='*95}")
print(f"OPTUNA SEARCH: {VARIASI_NAME.upper()} (EFFICIENTNET-B0 + FPN ONLY)")
print(f"YAML : {YAML_PATH.name}")
print(f"Trial epochs: {EPOCHS_SEARCH} │ Final epochs: {EPOCHS_FINAL}")
print(f"{'='*95}\n")

study.optimize(objective, n_trials=20)
# Out:
# [I 2025-11-22 18:28:21,722] A new study created in RDB with name: dental_caries_yolo12s_efficientnetb0_fpn_only
# ===============================================================================================
# OPTUNA SEARCH: YOLO12S_EFFICIENTNETB0_FPN_ONLY (EFFICIENTNET-B0 + FPN ONLY)
# YAML : yolo12s_efficientnetb0_fpn_only.yaml
# Trial epochs: 20 │ Final epochs: 500
# ===============================================================================================
#
# Ultralytics 8.3.230 🚀 Python-3.10.12 torch-2.9.1+cu128 CUDA:4 (NVIDIA H200, 143167MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=24, bgr=0.0, box=18.019512705506152, cache=disk, cfg=None, classes=None, close_mosaic=5, cls=1.1496870933552545, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dental-caries-13/data.yaml, degrees=0.0, deterministic=True, device=4, dfl=0.5720457300353086, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.00029375384576328325, lrf=0.006194745024628934, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=runs/optuna/yolo12s_efficientnetb0_fpn_only/yolo12s_efficientnetb0_fpn_only.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=trial_0000, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=10, perspective=0.0, plots=False, pose=12.0, pretrained=False, profile=False, project=runs/optuna/yolo12s_efficientnetb0_fpn_only, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/raid/tegar/jody/runs/optuna/yolo12s_efficientnetb0_fpn_only/trial_0000, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005399484409787432, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1   4007548  ultralytics.nn.modules.block.TorchVision     ['efficientnet_b0', 'DEFAULT', True, 2, True]
#   1                   0  1         0  ultralytics.nn.modules.conv.Index            [4]
#   2                   1  1      5376  ultralytics.nn.modules.conv.Conv             [40, 128, 1, 1]
#   3                   0  1         0  ultralytics.nn.modules.conv.Index            [6]
#   4                   3  1     29184  ultralytics.nn.modules.conv.Conv             [112, 256, 1, 1]
#   5                   0  1         0  ultralytics.nn.modules.conv.Index            [8]
#   6                   5  1    164864  ultralytics.nn.modules.conv.Conv             [320, 512, 1, 1]
#   7                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#   8             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#   9                  -1  1    345856  ultralytics.nn.modules.block.A2C2f           [768, 256, 1, False, -1]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 2]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1     86912  ultralytics.nn.modules.block.A2C2f           [384, 128, 1, False, -1]
#  13          [12, 9, 6]  1    822117  ultralytics.nn.modules.head.Detect           [7, [128, 256, 512]]
# YOLO12s_efficientnetb0_fpn_only summary: 320 layers, 5,461,857 parameters, 5,461,841 gradients, 12.9 GFLOPs
#
# Freezing layer 'model.13.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1111.1±402.6 MB/s, size: 40.1 KB)
# train: Scanning /raid/tegar/jody/dental-caries-13/train/labels.cache... 10341 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10341/10341 2.2Mit/s 0.0s
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous-frontalView-1727682033413_jpg.rf.0898e21fccbfb87c8cdbf95ff705c01d.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous-frontalView-1727682033413_jpg.rf.91fd1039ebfaf7e65d0222c50eb09048.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous-frontalView-1727682033413_jpg.rf.e960ee3b8f080332b5405cccab348fa7.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous-leftLateralView-1727332534215_jpg.rf.0518166cc1007b4379d393e062959b6e.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous-maxillaryView-1727415611006_jpg.rf.35a028e810f1c47712bea145e46d6708.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous-rightLateralView-1727876053493_jpg.rf.873415c52774b2362932598261955ef9.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous_003-007-1319-00_1733466947980_Left_Lateral_View_jpg.rf.a9232fae0436a3376ad7f2f091f42800.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous_003-007-1319-00_1733466947980_Left_Lateral_View_jpg.rf.b1528e9ed8f8c16802a9956aaefa7ecb.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous_003-007-1319-00_1733466947980_Left_Lateral_View_jpg.rf.e0a66ca6653f78dafd11d2e3031e1b54.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous_003-007-668-01_1729235647349_Mandibular_View_jpg.rf.57378e1edd2d25f48edbeffae74afd0a.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous_003-008-1439-01_1734006035878_Right_Lateral_View_jpg.rf.a2391495f68a160abe60a80642a7b877.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous_003-008-823-01_1729949111612_Left_Lateral_View_jpg.rf.200a6809d2778cd57ef96f7c58e343dd.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous_003-008-939-00_1730729761767_Left_Lateral_View_jpg.rf.e97ef525c1e5caaff27298eec82a05f1.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous_003_007_344_00_1728027849334_Left_Lateral_View_jpg.rf.3de4ad7d8c84ec7df58478d4a93e2ff9.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous_003_007_344_00_1728027849334_Left_Lateral_View_jpg.rf.8d2aa923e739259990cf0c122a8e1e64.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous_003_007_344_00_1728027849334_Left_Lateral_View_jpg.rf.daba023b09a4ef55610925f9aa89164f.jpg: 1 duplicate labels removed
# train: /raid/tegar/jody/dental-caries-13/train/images/anonymous_003_007_447_01_1728537828958_Right_Lateral_View_jpg.rf.9c54438cfb19825f115977973d5024de.jpg: 1 duplicate labels removed
# train: Caching images (11.8GB Disk): 100% ━━━━━━━━━━━━ 10341/10341 21.8Kit/s 0.5s
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1093.8±424.2 MB/s, size: 41.2 KB)
# val: Scanning /raid/tegar/jody/dental-caries-13/valid/labels.cache... 700 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 700/700 102.0Kit/s 0.0s
# val: /raid/tegar/jody/dental-caries-13/valid/images/anonymous_003-008-826-00_1729951922030_Maxillary_Occlusal_View_jpg.rf.b120d8b7b185dfce14fd7925a36462c2.jpg: 1 duplicate labels removed
# val: Caching images (0.8GB Disk): 100% ━━━━━━━━━━━━ 700/700 8.9Kit/s 0.1s
# optimizer: AdamW(lr=0.00029375384576328325, momentum=0.937) with parameter groups 88 weight(decay=0.0), 127 weight(decay=0.000607441996101086), 126 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /raid/tegar/jody/runs/optuna/yolo12s_efficientnetb0_fpn_only/trial_0000
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      11.6G      3.911      4.671      1.171        747        640: 100% ━━━━━━━━━━━╸ 429/431 4.0it/s 2:43<0.5s

# %% [markdown]
# ## 7. Simpan Best Hyperparameter

# %%
with open(JSON_PATH, "w") as f:
    json.dump(study.best_params, f, indent=4)
print(f"\nOPTIMASI SELESAI! Best Score: {study.best_value:.6f}")
print(f"Best params → {JSON_PATH}")
print(f"Log lengkap → {CSV_PATH}")

# %% [markdown]
# ## 8. Final Training → EfficientNet-B0 + FPN

# %%
# !pip install -q ultralytics --upgrade
from ultralytics import YOLO
import json
from pathlib import Path

with open(JSON_PATH) as f:
    best = json.load(f)

print("Best Hyperparameters (EfficientNet-B0 + FPN Only):")
for k, v in best.items():
    print(f" {k:12} → {v}")

model = YOLO(str(YAML_PATH))
model.train(
    data="dental-caries-10/data.yaml",
    imgsz=640,
    epochs=EPOCHS_FINAL,
    batch=best["batch"],
    device=0,
    project="runs/final",
    name=f"{VARIASI_NAME}_FINAL",
    exist_ok=True,
    pretrained=False,
    optimizer="AdamW",
    patience=50,
    cache="disk",
    plots=True,
    save=True,
    close_mosaic=50,
    lr0=best["lr0"],
    lrf=best["lrf"],
    weight_decay=best["weight_decay"],
    box=best["box"],
    cls=best["cls"],
    dfl=best["dfl"],
)
print(f"\nFINAL TRAINING EfficientNet-B0 + FPN ONLY SELESAI!")
print(f"Model terbaik → runs/final/{VARIASI_NAME}_FINAL/weights/best.pt")
